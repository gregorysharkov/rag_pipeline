# %%
import logging
import os

import openai
from dotenv import load_dotenv

# Configure logging
logger = logging.getLogger(__name__)

# Load environment variables from .env file
load_dotenv()

# Get API key from environment variables
api_key = os.getenv("OPENAI_API_KEY")
if not api_key:
    logger.error("OPENAI_API_KEY not found in environment variables")
    raise ValueError("OPENAI_API_KEY not found in environment variables")

# Initialize the OpenAI client
client = openai.OpenAI(api_key=api_key)

# %%
def generate_youtube_short_script(topic: str) -> str:
    """
    Generate a script for a YouTube short based on the given topic.

    Args:
        topic: The topic or theme for the YouTube short

    Returns:
        str: The generated script
    """
    logger.info(f"Generating script for topic: {topic}")
    try:
        response = client.chat.completions.create(
            model="gpt-4o",  # You can change this to a different model if needed
            messages=[
                {
                    "role": "system",
                    "content": "You are a creative script writer for engaging YouTube shorts.",
                },
                {
                    "role": "user",
                    "content": f"Write a script for a 60-second YouTube short about {topic}. "
                    f"The script should be attention-grabbing, informative, and end with a hook. "
                    f"Format it with clear sections for INTRO, MAIN CONTENT, and OUTRO."
                    f"start with a plan: key messages, hooks and structure of the script",
                },
            ],
            max_tokens=500,
            temperature=0.7,
        )
        logger.debug("Script generated successfully")
        return response.choices[0].message.content
    except Exception as e:
        error_msg = f"Error generating script: {str(e)}"
        logger.error(error_msg)
        raise Exception(error_msg)

# %%
print(generate_youtube_short_script(topic="Must have tools for AI/ML developer"))
# Out:
# **PLAN:**
#
# **Key Messages:**
# 1. Highlight the essential tools for AI/ML developers.
# 2. Emphasize the importance of these tools in streamlining workflows and enhancing productivity.
# 3. Encourage viewers to explore and utilize these tools for their own projects.
#
# **Hooks:**
# - Start with a bold statement about the importance of the right tools in AI/ML development.
# - Use engaging visuals and quick, dynamic shots to maintain viewer interest.
# - End with a thought-provoking question or challenge to encourage further engagement.
#
# **Structure:**
# 1. INTRO: Capture attention with a bold statement and set the stage for the main content.
# 2. MAIN CONTENT: Present the must-have tools with brief descriptions.
# 3. OUTRO: Wrap up with a compelling hook to encourage viewers to engage further.
#
# ---
#
# **SCRIPT:**
#
# **INTRO:**
#
# [Visual: Fast-paced montage of AI/ML projects in action]
#
# **Narrator:** "Unlocking the power of artificial intelligence isn't just about algorithms—it's about having the right tools in your toolkit! Let's dive into the must-haves for every AI/ML developer!"
#
# **MAIN CONTENT:**
#
# [Visual: Quick cuts of each tool being used]
#
# **Narrator:** "First up, **Jupyter Notebooks**. It's your interactive playground for data exploration and visualization. Perfect for prototyping and debugging."
#
# [Visual: Jupyter Notebook interface]
#
# **Narrator:** "Next, **TensorFlow** and **PyTorch**—these are the heavyweights of deep learning frameworks. Choose your fighter and get ready to build complex models with ease!"
#
# [Visual: TensorFlow and PyTorch logos with model visualizations]
#
# **Narrator:** "Need a place to collaborate? **GitHub** has got you covered. Version control, team collaboration, and open-source projects all in one place!"
#
# [Visual: GitHub interface with collaborative coding]
#
# **Narrator:** "And don't forget **Docker**! Containerize your applications to ensure they run seamlessly across different environments."
#
# [Visual: Docker logo with application deployment]
#
# **OUTRO:**
#
# [Visual: Montage of all tools coming together]
#
# **Narrator:** "These tools are just the beginning. Which one will you master first to revolutionize your AI projects? Let me know in the comments! And if you're ready to explore deeper, hit that subscribe button for more insights!"
#
# [Visual: Call-to-action overlay with subscribe button animation]
